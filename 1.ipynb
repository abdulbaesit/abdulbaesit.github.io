# %%
from pathlib import Path

from IPython.display import HTML, display

workspace = Path('/Users/abdulbasit/Desktop/portfolio-site')
output_path = workspace / 'assets' / 'profile-image.html'

html_text = '''<!doctype html>
<html data-theme="light">
<head>
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1">
    <style>
        .profile-image {
            width: 150px;
            height: 150px;
            max-width: 40vw;
            max-height: 40vw;
            border-radius: 50%;
            overflow: hidden;
            display: block;
            box-shadow: none;
            background-color: transparent;
        }

        .profile-image img {
            width: 140%;
            height: 140%;
            object-fit: cover;
            object-position: center 0%;
            transform: scale(1.3);
            transform-origin: center;
            display: block;
            border-radius: 50%;
        }
    </style>
</head>
<body>
    <div class="profile-image" role="img" aria-label="Abdul Basit">
        <img src="assets/me.png" alt="Abdul Basit" />
    </div>
</body>
</html>'''

output_path.write_text(html_text, encoding='utf-8')
print(f'Saved {output_path}')
display(HTML(html_text))
# Out:
# Saved /Users/abdulbasit/Desktop/portfolio-site/assets/profile-image.html
# <!doctype html>
# <html data-theme="light">
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <style>
#         .profile-image {
#             width: 150px;
#             height: 150px;
#             max-width: 40vw;
#             max-height: 40vw;
#             border-radius: 50%;
#             overflow: hidden;
#             display: block;
#             box-shadow: none;
#             background-color: transparent;
#         }
#
#         .profile-image img {
#             width: 140%;
#             height: 140%;
#             object-fit: cover;
#             object-position: center 0%;
#             transform: scale(1.3);
#             transform-origin: center;
#             display: block;
#             border-radius: 50%;
#         }
#     </style>
# </head>
# <body>
#     <div class="profile-image" role="img" aria-label="Abdul Basit">
#         <img src="assets/me.png" alt="Abdul Basit" />
#     </div>
# </body>
# </html>
